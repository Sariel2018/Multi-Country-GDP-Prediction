# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = 'checkpoints_mlp/'

# %%
df_list = []
for file in os.listdir(file_path):
    if '.csv' in file:
        print(file)
        df_temp = pd.read_csv(file_path + file, index_col=0)
        df_temp['data'] = file.replace('_best_params_res.csv', '')
        df_list.append(df_temp)

# %%
df_res = pd.concat(df_list)
df_res

# %%
for col in ['final model mae', 'final model mse', 'final model rmse', 'final model mape',
 'best val model mae', 'best val model mse', 'best val model rmse', 'best val model mape']:
    df_res[col] = df_res[col].apply(lambda x: x.replace(')', '').replace('tensor(', ''))
df_res

# %%
# df_res.to_excel('mlp_results.xlsx')

# %%
file_path = 'checkpoints_lstm/'

# %%
df_list = []
for file in os.listdir(file_path):
    if '.csv' in file:
        print(file)
        df_temp = pd.read_csv(file_path + file, index_col=0)
        df_temp['data'] = file.replace('_best_params_res.csv', '')
        df_list.append(df_temp)

# %%
df_res = pd.concat(df_list)
df_res

# %%
for col in ['final model mae', 'final model mse', 'final model rmse', 'final model mape',
 'best val model mae', 'best val model mse', 'best val model rmse', 'best val model mape']:
    df_res[col] = df_res[col].apply(lambda x: x.replace(')', '').replace('tensor(', ''))
df_res

# %%
# df_res.to_excel('lstm_results.xlsx')

# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = 'checkpoints_transformer/'

# %%
df_list = []
for file in os.listdir(file_path):
    if '.csv' in file:
        print(file)
        df_temp = pd.read_csv(file_path + file, index_col=0)
        df_temp['data'] = file.replace('_best_params_res.csv', '')
        df_list.append(df_temp)
# Out:
# train_dataset_mlp_13v_id_norm_6146_80-07_hbest_params_res.csv
# train_dataset_light_year_14v_6146_13-19_hbest_params_res.csv
# train_dataset_mlp_13v_id_norm_6146_13-19_hbest_params_res.csv
# train_dataset_mlp_13v_id_norm_6146_80-19_hbest_params_res.csv
# train_dataset_light_month_25v_6146_13-19_hbest_params_res.csv

# %%
df_res = pd.concat(df_list)
df_res
# Out:
#    embed_dim  repeat_dim  num_heads  num_layers      lr  batch_size  \
# 0       1024         100          8           3  0.0001          64
# 0        512         100          8           3  0.0001          64
# 0       1024         100          8           3  0.0001          64
# 0        512         100          8           3  0.0001          64
# 0       2048         100          8           3  0.0001          64
#
#    num_epochs  weight_decay  record_best_epoch  record_best_val_gdp_loss  ...  \
# 0        1000          0.01                264                  0.851618  ...
# 0        1000          0.01                110                  0.373241  ...
# 0        1000          0.01                138                  0.350869  ...
# 0        1000          0.01                725                  1.101031  ...
# 0        1000          0.01                401                  0.320350  ...
#
#    final model mape  best val model mae best val model mse  \
# 0    tensor(0.2795)      tensor(0.8817)     tensor(1.7984)
# 0    tensor(1.1394)      tensor(0.8003)     tensor(1.1114)
# 0    tensor(0.5597)      tensor(0.4693)     tensor(0.4105)
# 0    tensor(0.4113)      tensor(0.5910)     tensor(0.7588)
# 0    tensor(0.7844)      tensor(0.8246)     tensor(1.1713)
#
#   best val model rmse best val model mape train_data len test_data len  \
# 0      tensor(1.3411)      tensor(0.2769)            407            38
# 0      tensor(1.0542)      tensor(0.8647)            115            20
# 0      tensor(0.6407)      tensor(0.4929)            115            20
# 0      tensor(0.8711)      tensor(0.4039)            635            40
# 0      tensor(1.0823)      tensor(1.0391)            115            20
#
#   train_targets len test_targets len  \
# 0               407               38
# 0               115               20
# 0               115               20
# 0               635               40
# 0               115               20
#
#                                                 data
# 0  train_dataset_mlp_13v_id_norm_6146_80-07_hbest...
# 0  train_dataset_light_year_14v_6146_13-19_hbest_...
# 0  train_dataset_mlp_13v_id_norm_6146_13-19_hbest...
# 0  train_dataset_mlp_13v_id_norm_6146_80-19_hbest...
# 0  train_dataset_light_month_25v_6146_13-19_hbest...
#
# [5 rows x 25 columns]

# %%
for col in ['final model mae', 'final model mse', 'final model rmse', 'final model mape',
 'best val model mae', 'best val model mse', 'best val model rmse', 'best val model mape']:
    df_res[col] = df_res[col].apply(lambda x: x.replace(')', '').replace('tensor(', ''))
df_res
# Out:
#    embed_dim  repeat_dim  num_heads  num_layers      lr  batch_size  \
# 0       1024         100          8           3  0.0001          64
# 0        512         100          8           3  0.0001          64
# 0       1024         100          8           3  0.0001          64
# 0        512         100          8           3  0.0001          64
# 0       2048         100          8           3  0.0001          64
#
#    num_epochs  weight_decay  record_best_epoch  record_best_val_gdp_loss  ...  \
# 0        1000          0.01                264                  0.851618  ...
# 0        1000          0.01                110                  0.373241  ...
# 0        1000          0.01                138                  0.350869  ...
# 0        1000          0.01                725                  1.101031  ...
# 0        1000          0.01                401                  0.320350  ...
#
#    final model mape  best val model mae best val model mse  \
# 0            0.2795              0.8817             1.7984
# 0            1.1394              0.8003             1.1114
# 0            0.5597              0.4693             0.4105
# 0            0.4113              0.5910             0.7588
# 0            0.7844              0.8246             1.1713
#
#   best val model rmse best val model mape train_data len test_data len  \
# 0              1.3411              0.2769            407            38
# 0              1.0542              0.8647            115            20
# 0              0.6407              0.4929            115            20
# 0              0.8711              0.4039            635            40
# 0              1.0823              1.0391            115            20
#
#   train_targets len test_targets len  \
# 0               407               38
# 0               115               20
# 0               115               20
# 0               635               40
# 0               115               20
#
#                                                 data
# 0  train_dataset_mlp_13v_id_norm_6146_80-07_hbest...
# 0  train_dataset_light_year_14v_6146_13-19_hbest_...
# 0  train_dataset_mlp_13v_id_norm_6146_13-19_hbest...
# 0  train_dataset_mlp_13v_id_norm_6146_80-19_hbest...
# 0  train_dataset_light_month_25v_6146_13-19_hbest...
#
# [5 rows x 25 columns]

# %%
df_res.to_excel('transformer_res.xlsx')
